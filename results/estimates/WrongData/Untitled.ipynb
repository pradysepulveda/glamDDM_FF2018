# %%
import numpy as np
import pandas as pd

# %%
a = np.load('/Users/bdmlab/Documents/GiTs/glamFF2018/results/estimates/glam_full_individual.npy')

# %%
pd.DataFrame(a)
# Out:
#                                                     0
# 0   {'tau': 1.61, 'p_error': 0.05, 'gamma': -0.97,...
# 1   {'tau': 0.12, 'p_error': 0.05, 'gamma': -0.98,...
# 2   {'tau': 1.21, 'p_error': 0.05, 'gamma': 0.46, ...
# 3   {'tau': 2.88, 'p_error': 0.05, 'gamma': -0.83,...
# 4   {'tau': 4.96, 'p_error': 0.05, 'gamma': -0.69,...
# 5   {'tau': 0.26, 'p_error': 0.05, 'gamma': -0.94,...
# 6   {'tau': 0.36, 'p_error': 0.05, 'gamma': -0.9, ...
# 7   {'tau': 0.72, 'p_error': 0.05, 'gamma': -0.92,...
# 8   {'tau': 0.53, 'p_error': 0.05, 'gamma': -0.91,...
# 9   {'tau': 4.54, 'p_error': 0.05, 'gamma': -0.9, ...
# 10  {'tau': 0.37, 'p_error': 0.05, 'gamma': -0.71,...
# 11  {'tau': 1.78, 'p_error': 0.05, 'gamma': -0.5, ...
# 12  {'tau': 1.76, 'p_error': 0.05, 'gamma': -0.71,...
# 13  {'tau': 0.58, 'p_error': 0.05, 'gamma': 0.49, ...
# 14  {'tau': 0.67, 'p_error': 0.05, 'gamma': -0.21,...
# 15  {'tau': 2.86, 'p_error': 0.05, 'gamma': -0.28,...
# ...

# %%
np.load('/Users/bdmlab/Documents/GiTs/glamFF2018/results/estimates/glam_full_individual_Like.npy')
# Out:
# array([ {'tau': 1.6100000000000001, 'p_error': 0.050000001, 'gamma': -0.96999999999999997, 's': 0.0081720000000000004, 'b': 1.0, 'SNR': 190.83000000000001, 'v': 4.8000000000000001e-05, 't0': array([ 0.])},
#        {'tau': 0.12, 'p_error': 0.050000001, 'gamma': -0.97999999999999998, 's': 0.011299999999999999, 'b': 1.0, 'SNR': 130.66999999999999, 'v': 8.5000000000000006e-05, 't0': array([ 0.])},
#        {'tau': 1.21, 'p_error': 0.050000001, 'gamma': 0.46000000000000002, 's': 0.0094199999999999996, 'b': 1.0, 'SNR': 148.66999999999999, 'v': 6.0999999999999999e-05, 't0': array([ 0.])},
#        {'tau': 2.8799999999999999, 'p_error': 0.050000001, 'gamma': -0.82999999999999996, 's': 0.0088400000000000006, 'b': 1.0, 'SNR': 235.86000000000001, 'v': 3.8999999999999999e-05, 't0': array([ 0.])},
#        {'tau': 4.96, 'p_error': 0.050000001, 'gamma': -0.68999999999999995, 's': 0.0058729999999999997, 'b': 1.0, 'SNR': 87.540000000000006, 'v': 6.7000000000000002e-05, 't0': array([ 0.])},
# ...

# %%
import pickle

# %%
file_pi2 = open('/Users/bdmlab/Documents/GiTs/glamFF2018/individual_fit_like.obj', 'r')

# %%
object_pi2 = pickle.load(file_pi2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-04c5f27ad206> in <module>()
# ----> 1 object_pi2 = pickle.load(file_pi2)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import shelve
database_glma = shelve.open('/Users/bdmlab/Documents/GiTs/glamFF2018/individual_fit_like.db')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-33e4e22f1d8b> in <module>()
#       1 import shelve
# ----> 2 database_glma = shelve.open('/Users/bdmlab/Documents/GiTs/glamFF2018/individual_fit_like.db')
#
# /anaconda3/lib/python3.5/shelve.py in open(filename, flag, protocol, writeback)
#     241     """
#     242
# --> 243     return DbfilenameShelf(filename, flag, protocol, writeback)
#
# /anaconda3/lib/python3.5/shelve.py in __init__(self, filename, flag, protocol, writeback)
#     225     def __init__(self, filename, flag='c', protocol=None, writeback=False):
#     226         import dbm
# --> 227         Shelf.__init__(self, dbm.open(filename, flag), protocol, writeback)
#     228
#     229
#
# /anaconda3/lib/python3.5/dbm/__init__.py in open(file, flag, mode)
#      86     elif result == "":
#      87         # db type cannot be determined
# ...

# %%
import pymc3 as pm

# %%
vars(pm)
# Out:
# {'ADVI': pymc3.variational.inference.ADVI,
#  'AR': pymc3.distributions.timeseries.AR,
#  'AR1': pymc3.distributions.timeseries.AR1,
#  'ASVGD': pymc3.variational.inference.ASVGD,
#  'Approximation': pymc3.variational.opvi.Approximation,
#  'ArrayOrdering': pymc3.blocking.ArrayOrdering,
#  'Bernoulli': pymc3.distributions.discrete.Bernoulli,
#  'Beta': pymc3.distributions.continuous.Beta,
#  'BetaBinomial': pymc3.distributions.discrete.BetaBinomial,
#  'BinaryGibbsMetropolis': pymc3.step_methods.metropolis.BinaryGibbsMetropolis,
#  'BinaryMetropolis': pymc3.step_methods.metropolis.BinaryMetropolis,
#  'Binomial': pymc3.distributions.discrete.Binomial,
#  'Bound': pymc3.distributions.bound.Bound,
#  'CSG': pymc3.step_methods.sgmcmc.CSG,
#  'CallableTensor': pymc3.theanof.CallableTensor,
#  'Categorical': pymc3.distributions.discrete.Categorical,
#  'CategoricalGibbsMetropolis': pymc3.step_methods.metropolis.CategoricalGibbsMetropolis,
# ...

# %%
pm.dic()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f7ab386bbe2c> in <module>()
# ----> 1 pm.dic()
#
# AttributeError: module 'pymc3' has no attribute 'dic'

# %%
pm.dic
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-4b349ae3d32b> in <module>()
# ----> 1 pm.dic
#
# AttributeError: module 'pymc3' has no attribute 'dic'
