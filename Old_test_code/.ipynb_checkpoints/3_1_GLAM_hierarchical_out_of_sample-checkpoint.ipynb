# %%
import glam
import pandas as pd
import numpy as np
import os.path

import matplotlib.pyplot as plt

# %%
np.random.seed(23) # from random.org

# %% [markdown]
# # 3.1. Hierarchical GLAM estimation and out of sample prediction

# %% [markdown]
# ## Load data

# %%
# Load data
data = pd.read_csv('data/FF2018_data/GlamDataFF2018_Like.csv')
# Subset only necessary columns
data = data[['subject', 'trial', 'choice', 'rt',
             'item_value_0', 'item_value_1', 'item_value_2',
             'gaze_0', 'gaze_1', 'gaze_2']]
data.head()
# Out:
#    subject  trial  choice    rt  item_value_0  item_value_1  item_value_2  \
# 0        0      0       1  1782             1             7             3
# 1        0      1       1  1063             7             3             2
# 2        0      2       2  1171             3             1             2
# 3        0      3       0  1368             3             1             2
# 4        0      4       0  1476             6             1             3
#
#      gaze_0    gaze_1    gaze_2
# 0  0.096864  0.791638  0.111498
# 1  0.177738  0.500898  0.321364
# 2  0.534224  0.000000  0.465776
# 3  0.626604  0.000000  0.373396
# 4  0.340448  0.488794  0.170758

# %% [markdown]
# ## Split data in training and test sets

# %%
train_data = pd.DataFrame()
test_data = pd.DataFrame()

for subject in data.subject.unique():
    subject_data = data[data['subject'] == subject].copy().reset_index(drop=True)
    n_trials = len(subject_data)
    
    subject_train = subject_data.iloc[np.arange(0, n_trials, 2)].copy()
    subject_test = subject_data.iloc[np.arange(1, n_trials, 2)].copy()

    test_data = pd.concat([test_data, subject_test])
    train_data = pd.concat([train_data, subject_train])

test_data.to_csv('data/krajbich_2011_pnas/data_pnas2011_preprocessed_test.csv')
train_data.to_csv('data/krajbich_2011_pnas/data_pnas2011_preprocessed_train.csv')

print('Split data into training ({} trials) and test ({} trials) sets...'.format(len(train_data), len(test_data)))
# Out:
# Split data into training (1483 trials) and test (1483 trials) sets...

# %% [markdown]
# ## Hierarchical GLAM estimation

# %% [markdown]
# ### 1. full GLAM

# %%
# Fitting full GLAM
print('Fitting full GLAM hierarchically...')

glam_full = glam.GLAM(train_data)

if not os.path.exists('results/estimates/glam_full_hierarchical_cv.npy'):
    glam_full.make_model('hierarchical', gamma_bounds=(-1, 1), t0_val=0)
    glam_full.fit(method='ADVI', n_advi=200000)
else:
    print('  Found old parameter estimates in "results/estimates". Skipping estimation...')
    glam_full.estimates = np.load('results/estimates/glam_full_hierarchical_cv.npy')[()]
    
# Save parameter estimates
np.save('results/estimates/glam_full_hierarchical_cv.npy', glam_full.estimates)
pd.DataFrame(glam_full.estimates)
# Out:
# Fitting full GLAM hierarchically...
# Generating hierarchical model for 30 subjects...
# Fitting 1 model(s) using ADVI...
#   Fitting model 1 of 1...
# Average Loss = 13,017: 100%|██████████| 200000/200000 [18:51<00:00, 176.72it/s]
# Finished [100%]: Average Loss = 13,017
# /!\ Automatically setting parameter precision...
#        SNR  SNR_mu  SNR_sd    b  gamma  gamma_mu  gamma_sd  p_error         s  \
# 0    76.19   124.7   61.06  1.0   0.32      0.15       0.4     0.05  0.007920
# 1   122.23   124.7   61.06  1.0   0.40      0.15       0.4     0.05  0.008773
# 10  0.0  0.81    0.73    0.34  0.000077  0.000068  0.000035
# 11  0.0  0.13    0.73    0.34  0.000135  0.000068  0.000035
# 12  0.0  0.84    0.73    0.34  0.000061  0.000068  0.000035
# 13  0.0  1.14    0.73    0.34  0.000065  0.000068  0.000035
# 14  0.0  0.47    0.73    0.34  0.000095  0.000068  0.000035
# 15  0.0  0.89    0.73    0.34  0.000025  0.000068  0.000035
# 16  0.0  0.83    0.73    0.34  0.000060  0.000068  0.000035
# 17  0.0  0.99    0.73    0.34  0.000042  0.000068  0.000035
# 18  0.0  0.40    0.73    0.34  0.000113  0.000068  0.000035
# 19  0.0  0.38    0.73    0.34  0.000064  0.000068  0.000035
# 20  0.0  0.91    0.73    0.34  0.000042  0.000068  0.000035
# 21  0.0  0.52    0.73    0.34  0.000066  0.000068  0.000035
# 22  0.0  0.43    0.73    0.34  0.000051  0.000068  0.000035
# 23  0.0  0.58    0.73    0.34  0.000040  0.000068  0.000035
# 24  0.0  0.90    0.73    0.34  0.000023  0.000068  0.000035
# 25  0.0  0.80    0.73    0.34  0.000055  0.000068  0.000035
# 26  0.0  0.59    0.73    0.34  0.000088  0.000068  0.000035
# 27  0.0  0.90    0.73    0.34  0.000062  0.000068  0.000035
# 28  0.0  1.11    0.73    0.34  0.000044  0.000068  0.000035
# 29  0.0  0.17    0.73    0.34  0.000115  0.000068  0.000035

# %%
# Predictions
print('Predicting test set data using full GLAM...')
glam_full.exchange_data(test_data)

if not os.path.exists('results/predictions/glam_full_hierarchical_cv.csv'):
    glam_full.predict(n_repeats=50)
    glam_full.prediction.to_csv('results/predictions/glam_full_hierarchical_cv.csv', index=False)
else:
    print('  Found old hierarchical full GLAM predictions in "results/predictions". Skipping prediction...')
    glam_full.prediction = pd.read_csv('results/predictions/glam_full_hierarchical_cv.csv')

glam_full.prediction.head()
# Out:
# Predicting test set data using full GLAM...
# Replaced attached data (1483 trials) with new data (1483 trials)...
#    choice  repeat      rt  subject  trial  item_value_0    gaze_0  \
# 0     2.0     0.0  1512.0      0.0    0.0             7  0.177738
# 1     0.0     1.0  1944.0      0.0    0.0             7  0.177738
# 2     2.0     2.0  2073.0      0.0    0.0             7  0.177738
# 3     1.0     3.0  2150.0      0.0    0.0             7  0.177738
# 4     1.0     4.0  1609.0      0.0    0.0             7  0.177738
#
#    item_value_1    gaze_1  item_value_2    gaze_2
# 0             3  0.500898             2  0.321364
# 1             3  0.500898             2  0.321364
# 2             3  0.500898             2  0.321364
# 3             3  0.500898             2  0.321364
# 4             3  0.500898             2  0.321364

# %% [markdown]
# ### 1. no-bias GLAM

# %%
# Fitting no-bias GLAM
print('Fitting no-bias GLAM hierarchically...')

glam_nobias = glam.GLAM(train_data)

if not os.path.exists('results/estimates/glam_nobias_hierarchical_cv.npy'):
    glam_nobias.make_model('hierarchical', gamma_val=1.0, t0_val=0)
    glam_nobias.fit(method='ADVI', n_advi=200000)
else:
    print('  Found old parameter estimates in "results/estimates". Skipping estimation...')
    glam_nobias.estimates = np.load('results/estimates/glam_nobias_hierarchical_cv.npy')[()]
    
# Save parameter estimates
np.save('results/estimates/glam_nobias_hierarchical_cv.npy', glam_nobias.estimates)
pd.DataFrame(glam_nobias.estimates)
# Out:
# Fitting no-bias GLAM hierarchically...
# Generating hierarchical model for 30 subjects...
# Fitting 1 model(s) using ADVI...
#   Fitting model 1 of 1...
# Average Loss = 13,288: 100%|██████████| 200000/200000 [15:34<00:00, 214.10it/s]
# Finished [100%]: Average Loss = 13,288
# /!\ Automatically setting parameter precision...
#        SNR  SNR_mu  SNR_sd    b  gamma  p_error         s   t0   tau  tau_mu  \
# 0    66.49  120.03    67.0  1.0    1.0     0.05  0.006700  0.0  0.30    0.32
# 1   131.78  120.03    67.0  1.0    1.0     0.05  0.007714  0.0  0.45    0.32
# 2   130.76  120.03    67.0  1.0    1.0     0.05  0.009382  0.0  0.46    0.32
# 3    86.99  120.03    67.0  1.0    1.0     0.05  0.008925  0.0  0.35    0.32
# 4   109.71  120.03    67.0  1.0    1.0     0.05  0.006917  0.0  0.41    0.32
# 5   130.57  120.03    67.0  1.0    1.0     0.05  0.006814  0.0  0.22    0.32
# 6   231.62  120.03    67.0  1.0    1.0     0.05  0.005102  0.0  0.31    0.32
# 7   190.60  120.03    67.0  1.0    1.0     0.05  0.010175  0.0  0.12    0.32
# 8    15.76  120.03    67.0  1.0    1.0     0.05  0.002851  0.0  0.12    0.32
# 9   150.47  120.03    67.0  1.0    1.0     0.05  0.009748  0.0  0.24    0.32
# 10   95.07  120.03    67.0  1.0    1.0     0.05  0.007972  0.0  0.44    0.32
# 11   17.81  120.03    67.0  1.0    1.0     0.05  0.002475  0.0  0.03    0.32
# 12  112.21  120.03    67.0  1.0    1.0     0.05  0.008462  0.0  0.36    0.32
# 13   95.48  120.03    67.0  1.0    1.0     0.05  0.007131  0.0  0.44    0.32
# 14   18.16  120.03    67.0  1.0    1.0     0.05  0.002414  0.0  0.09    0.32
# 15  228.03  120.03    67.0  1.0    1.0     0.05  0.005736  0.0  0.44    0.32
# 16  155.68  120.03    67.0  1.0    1.0     0.05  0.011418  0.0  0.55    0.32
# 17  132.18  120.03    67.0  1.0    1.0     0.05  0.005798  0.0  0.49    0.32
# 18   73.07  120.03    67.0  1.0    1.0     0.05  0.008935  0.0  0.22    0.32
# 19  156.23  120.03    67.0  1.0    1.0     0.05  0.010428  0.0  0.25    0.32
# 20  173.74  120.03    67.0  1.0    1.0     0.05  0.008222  0.0  0.54    0.32
# 21  129.44  120.03    67.0  1.0    1.0     0.05  0.008807  0.0  0.25    0.32
# 22  114.56  120.03    67.0  1.0    1.0     0.05  0.007131  0.0  0.15    0.32
# 23  182.92  120.03    67.0  1.0    1.0     0.05  0.008225  0.0  0.36    0.32
# 24  246.86  120.03    67.0  1.0    1.0     0.05  0.005821  0.0  0.18    0.32
# 25  171.66  120.03    67.0  1.0    1.0     0.05  0.009519  0.0  0.30    0.32
# 26   96.67  120.03    67.0  1.0    1.0     0.05  0.009593  0.0  0.24    0.32
# 27  158.86  120.03    67.0  1.0    1.0     0.05  0.009024  0.0  0.57    0.32
# 28  138.91  120.03    67.0  1.0    1.0     0.05  0.006949  0.0  0.43    0.32
# 29   18.96  120.03    67.0  1.0    1.0     0.05  0.002360  0.0  0.06    0.32
#
#     tau_sd         v      v_mu      v_sd
# 0     0.18  0.000114  0.000076  0.000038
# 1     0.18  0.000066  0.000076  0.000038
# 2     0.18  0.000069  0.000076  0.000038
# 3     0.18  0.000093  0.000076  0.000038
# 4     0.18  0.000064  0.000076  0.000038
# 5     0.18  0.000052  0.000076  0.000038
# 6     0.18  0.000023  0.000076  0.000038
# 7     0.18  0.000051  0.000076  0.000038
# 8     0.18  0.000184  0.000076  0.000038
# 9     0.18  0.000062  0.000076  0.000038
# 10    0.18  0.000082  0.000076  0.000038
# 11    0.18  0.000137  0.000076  0.000038
# 12    0.18  0.000066  0.000076  0.000038
# 13    0.18  0.000071  0.000076  0.000038
# 14    0.18  0.000132  0.000076  0.000038
# 15    0.18  0.000025  0.000076  0.000038
# 16    0.18  0.000065  0.000076  0.000038
# 17    0.18  0.000047  0.000076  0.000038
# 18    0.18  0.000119  0.000076  0.000038
# 19    0.18  0.000067  0.000076  0.000038
# 20    0.18  0.000044  0.000076  0.000038
# 21    0.18  0.000071  0.000076  0.000038
# 22    0.18  0.000055  0.000076  0.000038
# 23    0.18  0.000042  0.000076  0.000038
# 24    0.18  0.000024  0.000076  0.000038
# 25    0.18  0.000062  0.000076  0.000038
# 26    0.18  0.000092  0.000076  0.000038
# 27    0.18  0.000067  0.000076  0.000038
# 28    0.18  0.000047  0.000076  0.000038
# 29    0.18  0.000125  0.000076  0.000038

# %%
# Predictions
print('Predicting test set data using no-bias GLAM...')
glam_nobias.exchange_data(test_data)

if not os.path.exists('results/predictions/glam_nobias_hierarchical_cv.csv'):
    glam_nobias.predict(n_repeats=50)
    glam_nobias.prediction.to_csv('results/predictions/glam_nobias_hierarchical_cv.csv', index=False)
else:
    print('  Found old hierarchical no-bias GLAM predictions in "results/predictions". Skipping prediction...')
    glam_nobias.prediction = pd.read_csv('results/predictions/glam_nobias_hierarchical_cv.csv')

glam_nobias.prediction.head()
# Out:
# Predicting test set data using no-bias GLAM...
# Replaced attached data (1483 trials) with new data (1483 trials)...
#    choice  repeat      rt  subject  trial  item_value_0    gaze_0  \
# 0     0.0     0.0  1219.0      0.0    0.0             7  0.177738
# 1     0.0     1.0  1473.0      0.0    0.0             7  0.177738
# 2     0.0     2.0  1095.0      0.0    0.0             7  0.177738
# 3     0.0     3.0  1138.0      0.0    0.0             7  0.177738
# 4     0.0     4.0  1456.0      0.0    0.0             7  0.177738
#
#    item_value_1    gaze_1  item_value_2    gaze_2
# 0             3  0.500898             2  0.321364
# 1             3  0.500898             2  0.321364
# 2             3  0.500898             2  0.321364
# 3             3  0.500898             2  0.321364
# 4             3  0.500898             2  0.321364

# %% [markdown]
# ## 2. Plot fit

# %%
print('Close Figure to continue...')
glam.plot_fit(test_data, [glam_full.prediction, glam_nobias.prediction]);
plt.show()
# Out:
# Close Figure to continue...
